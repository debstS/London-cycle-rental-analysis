# %% [markdown]
# <a href="https://colab.research.google.com/github/debstS/London-cycle-rental-analysis/blob/main/Cycle_rental_final_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to mount Google drive files for accessing from within Google Colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import glob

# %%
#copy and paste the path where the dataset is stored in your computer

os.chdir("/content/drive/MyDrive/TFL Cycle rental analysis - datasets")

# %%
# Step 1: List all CSV files in the directory

csv_files = glob.glob("*.csv")  # Assumes all CSV files are in the same directory

#csv_files

# Step 2: Read each CSV file and store them in a list
df_list = []
for file in csv_files:
  #print(file)
    df = pd.read_csv(file,low_memory = False)
    df.rename(columns = {'Rental Id':'Number', 'Duration':'Total duration', 'Bike Id':'Bike number', 'End Date':'End date', 'EndStation Id':'End station number', 'EndStation Name':'End station', 'Start Date':'Start date', 'StartStation Id':'Start station number','StartStation Name':'Start station'}, inplace=True)
    #df = df[['Number', 'Start date','Start station number','Start station','End date','End station number','End station','Bike number','Total duration']]
    #df = df.reindex(columns=['mean',0,1,2,3,4])
    df_list.append(df)

# %%
total_records_in_142csv_files = 0
for i, dfi in enumerate(df_list):
  #print(dfi.shape[0])
  total_records_in_142csv_files = total_records_in_142csv_files + dfi.shape[0]
total_records_in_142csv_files #30786752
# Out:
# 30786752

# %%
# #import polars as pl

df1 = pd.DataFrame({"A":[1,2,3], "B":[87,88,30]})
df2 = pd.DataFrame({"B":[4,5,6], "A":[1,2,3], "C":['a','c','c']})

df = pd.concat([df1, df2])
df
# Out:
#    A   B    C
# 0  1  87  NaN
# 1  2  88  NaN
# 2  3  30  NaN
# 0  1   4    a
# 1  2   5    c
# 2  3   6    c

# %%
final_df = pd.DataFrame()
for i_list, dfi_list in enumerate(df_list):
  final_df = pd.concat([final_df, dfi_list], ignore_index=True)

final_df.shape
# Out:
# (30786752, 11)

# %%
#final_df.head()
final_df[final_df['Number'] == 127293433]
# Out:
#              Number Total duration  Bike number          End date  \
# 21722499  127293433        15m 45s        57158  2022-12-05 00:14
#
#          End station number                              End station  \
# 21722499               1182  Notting Hill Gate Station, Notting Hill
#
#                 Start date Start station number                Start station  \
# 21722499  2022-12-04 23:58                 1152  Marylebone Lane, Marylebone
#
#          Bike model  Total duration (ms)
# 21722499    CLASSIC             945616.0

# %%
df_list[5].head(4)
# Out:
#       Number  Total duration  Bike number          End date  \
# 0  105305967            7260        18247  07/02/2021 21:32
# 1  105246421            4140        16694  03/02/2021 20:28
# 2  105320173             720        17329  09/02/2021 19:39
# 3  105255530             300         9078  04/02/2021 15:49
#
#    End station number                                   End station  \
# 0                 785  Aquatic Centre, Queen Elizabeth Olympic Park
# 1                 785  Aquatic Centre, Queen Elizabeth Olympic Park
# 2                  57                  Guilford Street , Bloomsbury
# 3                 386                             Moor Street, Soho
#
#          Start date  Start station number  \
# 0  07/02/2021 19:31                   785
# 1  03/02/2021 19:19                   785
# 2  09/02/2021 19:27                   804
# 3  04/02/2021 15:44                    88
#
#                                   Start station
# 0  Aquatic Centre, Queen Elizabeth Olympic Park
# ...

# %%
df_list[140].head(4)
# Out:
#       Number        Start date  Start station number            Start station  \
# 0  136236504  2023-12-14 23:59                  1052       Soho Square , Soho
# 1  136236505  2023-12-14 23:59                  1071    Tower Gardens , Tower
# 2  136236506  2023-12-14 23:59                200230  Maplin Street, Mile End
# 3  136236507  2023-12-14 23:59                  1163     Wardour Street, Soho
#
#            End date  End station number                 End station  \
# 0  2023-12-15 00:08                1011  Argyle Street, Kings Cross
# 1  2023-12-15 00:05              200021    Hermitage Court, Wapping
# 2  2023-12-15 00:07              200030    Driffield Road, Old Ford
# 3  2023-12-15 00:17              200151      Hoxton Station, Hoxton
#
#    Bike number Bike model Total duration  Total duration (ms)
# 0        41844    CLASSIC          9m 2s               542155
# 1        41687    CLASSIC         5m 29s               329770
# ...

# %%
pd_list = pd.DataFrame({'col':df_list})
pd_list.head(5)
# Out:
#                                                  col
# 0         Rental Id  Duration  Bike Id          E...
# 1         Rental Id  Duration  Bike Id          E...
# 2         Rental Id  Duration  Bike Id          E...
# 3         Rental Id  Duration  Bike Id          E...
# 4         Rental Id  Duration  Bike Id          E...

# %%
import pandas as pd

# Assuming df1 and df2 are your DataFrames

# Concatenate the DataFrames along the rows
#concatenated_df = pd.concat([df1, df2], ignore_index=True)

#If you want to keep all columns from both DataFrames:
#concatenated_df = pd.concat([df1, df2], ignore_index=True, sort=False)

#If you want to keep only unique columns from both DataFrames:
concatenated_df = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()

# ignore_index=True ensures that the index is reset to maintain a continuous index in the resulting DataFrame

# Example:
# df1:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# df2:
#    A  C  D
# 0  7  8  9
# 1  10 11 12

# concatenated_df:
#     A   B   C     D
# 0   1   2   3   NaN
# 1   4   5   6   NaN
# 2   7  NaN  8   9
# 3  10  NaN  11  12

# %%
dfs[141].head(1)
# Out:
#       Number        Start date  Start station number  \
# 0  136450327  2023-12-31 23:59                  3433
#
#                      Start station          End date  End station number  \
# 0  Sadlers Sports Centre, Finsbury  2024-01-01 00:19                3433
#
#                        End station  Bike number Bike model Total duration  \
# 0  Sadlers Sports Centre, Finsbury        17711    CLASSIC         20m 6s
#
#    Total duration (ms)
# 0              1206838

# %%
dfs[141].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209428 entries, 0 to 209427
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Number                209428 non-null  int64
#  1   Start date            209428 non-null  object
#  2   Start station number  209428 non-null  int64
#  3   Start station         209428 non-null  object
#  4   End date              209428 non-null  object
#  5   End station number    209428 non-null  int64
#  6   End station           209428 non-null  object
#  7   Bike number           209428 non-null  int64
#  8   Bike model            209428 non-null  object
#  9   Total duration        209428 non-null  object
#  10  Total duration (ms)   209428 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 17.6+ MB

# %%
dfs[21].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296473 entries, 0 to 296472
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Rental Id          296473 non-null  int64
#  1   Duration           296473 non-null  int64
#  2   Bike Id            296473 non-null  int64
#  3   End Date           296473 non-null  object
#  4   EndStation Id      296473 non-null  int64
#  5   EndStation Name    296473 non-null  object
#  6   Start Date         296473 non-null  object
#  7   StartStation Id    296473 non-null  int64
#  8   StartStation Name  296473 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 20.4+ MB

# %%
dfs[141].head(5)
# Out:
#       Number        Start date  Start station number  \
# 0  136450327  2023-12-31 23:59                  3433
# 1  136450328  2023-12-31 23:59                200094
# 2  136450329  2023-12-31 23:59                  1196
# 3  136450330  2023-12-31 23:59                  1220
# 4  136450331  2023-12-31 23:59                   964
#
#                      Start station          End date  End station number  \
# 0  Sadlers Sports Centre, Finsbury  2024-01-01 00:19                3433
# 1        St. Bride Street, Holborn  2024-01-01 00:50                1135
# 2      Vincent Square, Westminster  2024-01-01 00:16                1196
# 3  Imperial College, Knightsbridge  2024-01-01 00:12                3464
# 4          Bath Street, St. Luke's  2024-01-01 00:32                3437
#
#                        End station  Bike number Bike model Total duration  \
# 0  Sadlers Sports Centre, Finsbury        17711    CLASSIC         20m 6s
# ...

# %%
dfs[21].head(4)
# Out:
#    Rental Id  Duration  Bike Id          End Date  EndStation Id  \
# 0  108236168      1080      461  28/05/2021 09:17            452
# 1  108248572       840    19135  28/05/2021 15:32            841
# 2  108240926      1140    20426  28/05/2021 12:11            624
# 3  108165670       420    18717  26/05/2021 09:03            772
#
#                    EndStation Name        Start Date  StartStation Id  \
# 0       St. Katharine's Way, Tower  28/05/2021 08:59              134
# 1          Tower Wharf, Bermondsey  28/05/2021 15:18              134
# 2  Courland Grove, Wandsworth Road  28/05/2021 11:52              624
# 3         Binfield Road, Stockwell  26/05/2021 08:56              624
#
#                  StartStation Name
# 0     Wapping High Street, Wapping
# 1     Wapping High Street, Wapping
# 2  Courland Grove, Wandsworth Road
# 3  Courland Grove, Wandsworth Road

# %%
len(dfs)
# Out:
# 142

# %%
# Step 3: Merge DataFrames
merged_df = pd.concat(dfs, ignore_index=True)

# %%
merged_df.shape
# Out:
# (30786752, 20)

# %%
merged_df.head()
# Out:
#      Rental Id  Duration  Bike Id          End Date  EndStation Id  \
# 0  104820582.0    1620.0     22.0  03/01/2021 15:14           11.0
# 1  104816169.0    1740.0  10755.0  03/01/2021 13:26          542.0
# 2  104757113.0    1620.0  18908.0  30/12/2020 15:00          239.0
# 3  104749458.0     780.0  18499.0  30/12/2020 09:21          766.0
# 4  104788389.0    5400.0  15668.0  01/01/2021 16:29          655.0
#
#                  EndStation Name        Start Date  StartStation Id  \
# 0   Brunswick Square, Bloomsbury  03/01/2021 14:47            542.0
# 1         Salmon Lane, Limehouse  03/01/2021 12:57            546.0
# 2  Warren Street Station, Euston  30/12/2020 14:33            779.0
# 3         Ram Street, Wandsworth  30/12/2020 09:08            653.0
# 4          Crabtree Lane, Fulham  01/01/2021 14:59            655.0
#
#                   StartStation Name  Number Start date Start station number  \
# ...

# %%
# Step 4: Write the merged DataFrame to a new CSV file
merged_df.to_csv("merged_file.csv", index=False)

print("Merged file created successfully.")
